# %% [markdown]
# ## Project 2 - Data Cleansing Practice on Zillow Data

# %% [markdown]
# In this week, we’ll practice how to do regular cleansing in Python with a real-world dataset – Zillow dataset. This Zillow dataset contains abundant missing data and will provide you a good environment to practice your skills on data cleaning.

# %% [markdown]
# This step-by-step project will illustrate you various ways to impute missing values.

# %%
# Start with importing essentials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 1. Read the train set and property set of Zillow dataset, and name them as train and properties.

# %%
p16 = pd.read_csv("Project 2 data/properties_2016.csv", low_memory=False)
p16['year'] = 2016

# %%
p16.head(10)
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
# 5  10898347                    NaN                       NaN           NaN
# 6  10933547                    NaN                       NaN           NaN
# 7  10940747                    NaN                       NaN           NaN
# 8  10954547                    NaN                       NaN           NaN
# 9  10976347                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
# 5          0.0         0.0                  4.0                    7.0
# 6          0.0         0.0                  NaN                    NaN
# 7          0.0         0.0                  NaN                    NaN
# 8          0.0         0.0                  NaN                    NaN
# 9          0.0         0.0                  3.0                    7.0
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# 0                NaN         NaN  ...              NaN            NaN
# 1                NaN         NaN  ...              NaN            NaN
# 2                NaN         NaN  ...              NaN            NaN
# 3                NaN         NaN  ...              1.0            NaN
# 4                NaN         NaN  ...              NaN            NaN
# 5                NaN         NaN  ...              1.0            NaN
# 6                NaN         NaN  ...              NaN            NaN
# 7                NaN         NaN  ...              1.0            NaN
# 8                NaN         NaN  ...              NaN            NaN
# 9                NaN         NaN  ...              1.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2015.0
# 1                         NaN            27516.0          2015.0
# 2                    650756.0          1413387.0          2015.0
# 3                    571346.0          1156834.0          2015.0
# 4                    193796.0           433491.0          2015.0
# 5                    176383.0           283315.0          2015.0
# 6                    397945.0           554573.0          2015.0
# 7                    101998.0           688486.0          2015.0
# 8                         NaN                9.0          2015.0
# 9                    218440.0           261201.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               762631.0   20800.37                 NaN                 NaN
# 3               585488.0   14557.57                 NaN                 NaN
# 4               239695.0    5725.17                 NaN                 NaN
# 5               106932.0    3661.28                 NaN                 NaN
# 6               156628.0    6773.34                 NaN                 NaN
# 7               586488.0    7857.84                 NaN                 NaN
# 8                    9.0        NaN                 NaN                 NaN
# 9                42761.0    4054.76                 NaN                 NaN
#
#    censustractandblock
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
#
# [10 rows x 58 columns]

# %%
p17 = pd.read_csv("Project 2 data/properties_2017.csv", low_memory=False)
p17['year'] = 2017
p17.head(10)
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
# 5  10898347                    NaN                       NaN           NaN
# 6  10933547                    NaN                       NaN           NaN
# 7  10940747                    NaN                       NaN           NaN
# 8  10954547                    NaN                       NaN           NaN
# 9  10976347                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
# 5          0.0         0.0                  4.0                    4.0
# 6          0.0         0.0                  NaN                    NaN
# 7          0.0         0.0                  NaN                    NaN
# 8          0.0         0.0                  NaN                    NaN
# 9          0.0         0.0                  3.0                    4.0
#
#    calculatedbathnbr  decktypeid  ...  fireplaceflag  \
# 0                NaN         NaN  ...            NaN
# 1                NaN         NaN  ...            NaN
# 2                NaN         NaN  ...            NaN
# 3                NaN         NaN  ...            NaN
# 4                NaN         NaN  ...            NaN
# 5                NaN         NaN  ...            NaN
# 6                NaN         NaN  ...            NaN
# 7                NaN         NaN  ...            NaN
# 8                NaN         NaN  ...            NaN
# 9                NaN         NaN  ...            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                         NaN                9.0          2016.0
# 1                         NaN            27516.0          2015.0
# 2                    660680.0          1434941.0          2016.0
# 3                    580059.0          1174475.0          2016.0
# 4                    196751.0           440101.0          2016.0
# 5                    179072.0           287634.0          2016.0
# 6                    404013.0           563029.0          2016.0
# 7                    103553.0           698984.0          2016.0
# 8                         NaN                9.0          2016.0
# 9                    221771.0           265184.0          2016.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                    9.0        NaN                 NaN                 NaN
# 1                27516.0        NaN                 NaN                 NaN
# 2               774261.0   20800.37                 NaN                 NaN
# 3               594416.0   14557.57                 NaN                 NaN
# 4               243350.0    5725.17                 NaN                 NaN
# 5               108562.0    3661.28                 NaN                 NaN
# 6               159016.0    6773.34                 NaN                 NaN
# 7               595431.0    7857.84                 NaN                 NaN
# 8                    9.0        NaN                 NaN                 NaN
# 9                43413.0    4054.76                 NaN                 NaN
#
#    censustractandblock  year
# 0                  NaN  2017
# 1                  NaN  2017
# 2                  NaN  2017
# 3                  NaN  2017
# 4                  NaN  2017
# 5                  NaN  2017
# 6                  NaN  2017
# 7                  NaN  2017
# 8                  NaN  2017
# 9                  NaN  2017
#
# [10 rows x 59 columns]

# %%
t16 = pd.read_csv("Project 2 data/train_2016_v2.csv", low_memory=False)
t16.head(10)
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02
# 5  11509835   -0.2705      2016-01-02
# 6  12286022    0.0440      2016-01-02
# 7  17177301    0.1638      2016-01-02
# 8  14739064   -0.0030      2016-01-02
# 9  14677559    0.0843      2016-01-03

# %%
t17 = pd.read_csv("Project 2 data/train_2017.csv", low_memory=False)
t17.head(10)
# Out:
#    parcelid  logerror transactiondate
# 0  14297519  0.025595      2017-01-01
# 1  17052889  0.055619      2017-01-01
# 2  14186244  0.005383      2017-01-01
# 3  12177905 -0.103410      2017-01-01
# 4  10887214  0.006940      2017-01-01
# 5  17143294 -0.020526      2017-01-01
# 6  12095076 -0.001011      2017-01-01
# 7  12069064  0.101723      2017-01-01
# 8  12790562 -0.040966      2017-01-02
# 9  11542646 -0.036763      2017-01-02

# %%
prop = p16.append(p17)

# %%
train = t16.append(t17)

# %% [markdown]
# #### 2. Merge train and properties to one dataframe on parcelid and call it as df_train. Drop the column of 'parcelid' and 'transactiondate'. Check the first 5 rows to see how this merged dataset looks like.

# %%
df_train = pd.merge(prop, train, on='parcelid').drop(['parcelid', 'transactiondate'], axis = 1)

# %%
df_train.head(5)
# Out:
#    airconditioningtypeid  architecturalstyletypeid  basementsqft  bathroomcnt  \
# 0                    NaN                       NaN           NaN          5.0
# 1                    NaN                       NaN           NaN          5.0
# 2                    NaN                       NaN           NaN          2.0
# 3                    NaN                       NaN           NaN          2.0
# 4                    NaN                       NaN           NaN          1.5
#
#    bedroomcnt  buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# 0         4.0                  NaN                    NaN                5.0
# 1         4.0                  NaN                    NaN                5.0
# 2         3.0                  NaN                    NaN                2.0
# 3         3.0                  NaN                    NaN                2.0
# 4         3.0                  NaN                    NaN                1.5
#
#    decktypeid  finishedfloor1squarefeet  ...  structuretaxvaluedollarcnt  \
# 0         NaN                    1968.0  ...                    494390.0
# 1         NaN                    1968.0  ...                    501928.0
# 2        66.0                    1444.0  ...                    128881.0
# 3        66.0                    1444.0  ...                    130845.0
# 4        66.0                    1698.0  ...                    190508.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           859741.0          2015.0               365351.0    9608.74
# 1           872850.0          2016.0               370922.0    9673.46
# 2           429608.0          2015.0               300727.0    5494.04
# 3           436157.0          2016.0               305312.0    5538.80
# 4           282303.0          2015.0                91795.0    2954.74
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  year  logerror
# 0                 NaN                 NaN         6.111001e+13  2016 -0.013099
# 1                 NaN                 NaN         6.111001e+13  2017 -0.013099
# 2                 NaN                 NaN         6.111001e+13  2016  0.073985
# 3                 NaN                 NaN         6.111001e+13  2017  0.073985
# 4                 NaN                 NaN         6.111001e+13  2016  0.071886
#
# [5 rows x 59 columns]

# %% [markdown]
# #### 3.  (a) Generate a dataframe called missing_df from df_train, in which there are two columns, one is the column names of our features, the other column is the missing_count (the number of missing values) of that feature. The table should be ordered by missing_count decendingly.

# %%
missing_df = df_train.isna().sum().to_frame()

# %%
missing_df = missing_df.reset_index().rename(columns = {'index':'feature_name', 0:'missing_count'})

# %%
missing_df = missing_df.sort_values(by='missing_count', ascending=False)

# %%
missing_df.head(10)
# Out:
#                 feature_name  missing_count
# 5        buildingclasstypeid         335713
# 12      finishedsquarefeet13         335626
# 2               basementsqft         335590
# 40               storytypeid         335590
# 45        yardbuildingsqft26         335446
# 48             fireplaceflag         334988
# 1   architecturalstyletypeid         334840
# 42    typeconstructiontypeid         334732
# 15       finishedsquarefeet6         334172
# 8                 decktypeid         333228

# %% [markdown]
# #### 3.(b) Draw a horizontal bar plot to visualize it.

# %%
fig = plt.figure(figsize=(10, 60))
ax = fig.add_subplot(111)
ax.barh(missing_df['feature_name'], missing_df['missing_count'])
# Out:
# <BarContainer object of 59 artists>

# %%
di

# %% [markdown]
# #### 4. Generate the correlation matrix for all the numerical features, and plot it by using heatmap or related visualization methods.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335776 entries, 0 to 335775
# Data columns (total 59 columns):
# airconditioningtypeid           107623 non-null float64
# architecturalstyletypeid        936 non-null float64
# basementsqft                    186 non-null float64
# bathroomcnt                     335601 non-null float64
# bedroomcnt                      335601 non-null float64
# buildingclasstypeid             63 non-null float64
# buildingqualitytypeid           214377 non-null float64
# calculatedbathnbr               332216 non-null float64
# decktypeid                      2548 non-null float64
# finishedfloor1squarefeet        25851 non-null float64
# calculatedfinishedsquarefeet    334084 non-null float64
# finishedsquarefeet12            319156 non-null float64
# finishedsquarefeet13            150 non-null float64
# finishedsquarefeet15            13174 non-null float64
# finishedsquarefeet50            25851 non-null float64
# finishedsquarefeet6             1604 non-null float64
# fips                            335601 non-null float64
# fireplacecnt                    35816 non-null float64
# fullbathcnt                     332216 non-null float64
# garagecarcnt                    110992 non-null float64
# garagetotalsqft                 110992 non-null float64
# hashottuborspa                  7781 non-null object
# heatingorsystemtypeid           211498 non-null float64
# latitude                        335601 non-null float64
# longitude                       335601 non-null float64
# lotsizesquarefeet               298855 non-null float64
# poolcnt                         68152 non-null float64
# poolsizesum                     3676 non-null float64
# pooltypeid10                    3239 non-null float64
# pooltypeid2                     4542 non-null float64
# pooltypeid7                     63563 non-null float64
# propertycountylandusecode       335600 non-null object
# propertylandusetypeid           335601 non-null float64
# propertyzoningdesc              217498 non-null object
# rawcensustractandblock          335601 non-null float64
# regionidcity                    329081 non-null float64
# regionidcounty                  335601 non-null float64
# regionidneighborhood            133921 non-null float64
# regionidzip                     335458 non-null float64
# roomcnt                         335601 non-null float64
# storytypeid                     186 non-null float64
# threequarterbathnbr             44255 non-null float64
# typeconstructiontypeid          1044 non-null float64
# unitcnt                         218142 non-null float64
# yardbuildingsqft17              10082 non-null float64
# yardbuildingsqft26              330 non-null float64
# yearbuilt                       333726 non-null float64
# numberofstories                 76404 non-null float64
# fireplaceflag                   788 non-null object
# structuretaxvaluedollarcnt      334723 non-null float64
# taxvaluedollarcnt               335598 non-null float64
# assessmentyear                  335601 non-null float64
# landtaxvaluedollarcnt           335596 non-null float64
# taxamount                       335576 non-null float64
# taxdelinquencyflag              9366 non-null object
# taxdelinquencyyear              9366 non-null float64
# censustractandblock             333953 non-null float64
# year                            335776 non-null int64
# logerror                        335776 non-null float64
# dtypes: float64(53), int64(1), object(5)
# memory usage: 153.7+ MB

# %%
df_train.select_dtypes(include=['float64']).columns
# Out:
# Index(['airconditioningtypeid', 'architecturalstyletypeid', 'basementsqft',
#        'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertylandusetypeid', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'structuretaxvaluedollarcnt', 'taxvaluedollarcnt',
#        'assessmentyear', 'landtaxvaluedollarcnt', 'taxamount',
#        'taxdelinquencyyear', 'censustractandblock', 'logerror'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111)
corr = df_train.select_dtypes(include=['float64']).corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# #### 5. From the results from Step 4, please list those features having a strong correlation. Generate a list called dropcols, and put those redundent variables into it.

# %%
corr_tab = df_train.select_dtypes(include=['float64']).corr().abs().unstack().to_frame().reset_index().rename(columns = {0:"correlation"})

# %%
strong_corr = corr_tab[(corr_tab['correlation'] > 0.9) & (corr_tab['correlation'] != 1)].sort_values(by='correlation', ascending=False)

# %%
dropcols = strong_corr['level_0'].to_list()

# %% [markdown]
# #### 6. Some variables where it is NA can be considered as the object does not exist. Such as 'hashottuborspa', if it is NA, we can assume the house doesn't contain the hot tub or spa. So we need to fix this kind of variables.

# %% [markdown]
# (a) Fix the hashottuborspa variable, fill the na part as None.

# %%
df_train['hashottuborspa'].head(10)
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: hashottuborspa, dtype: object

# %%
df_train.loc[df_train['hashottuborspa'].isna(), 'hashottuborspa'] = None

# %% [markdown]
# (b) Assume if the pooltype id and its related features is null then pool/hottub doesn't exist.

# %%
df_train.loc[df_train['hashottuborspa'] == None, ['pooltypeid2', 'pooltypeid7', 'pooltypeid10', 'hashottuborspa']] = None

# %% [markdown]
# (c) taxdeliquencyflag - assume if it is null then doesn't exist

# %%
df_train['taxdelinquencyflag'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: taxdelinquencyflag, dtype: object

# %%
df_train.loc[df_train['taxdelinquencyflag'].isna(), 'taxdelinquencyflag'] = None

# %% [markdown]
# (d) If Null in garage count (garagecarcnt) it means there are no garages, and no garage means the size (garagetotalsqft) is 0 by default

# %%
df_train.loc[df_train['garagecarcnt'].isna(), 'garagetotalsqft'] = 0

# %% [markdown]
# #### 7. There are more missing values in the 'poolsizesum' than in 'poolcnt'. Fill in median values for poolsizesum where pool count is >0 and missing.

# %%
df_train['poolsizesum'].median()
# Out:
# 500.0

# %%
df_train.loc[(df_train['poolcnt'] > 0) | (df_train['poolcnt'].isna()), 'poolsizesum'] = df_train['poolsizesum'].median()

# %% [markdown]
# #### 8. The number of missing value of 'fireplaceflag' is more than the 'fireplacecnt'. So we need to mark the missing 'fireplaceflag' as Yes when fireplacecnt>0, then the rest of 'fireplaceflag' should be marked as No. Then for the missing part in fireplacecnt, we can consider the number of fire place is 0.

# %%
df_train.loc[(df_train['fireplaceflag'].isna()) & df_train['fireplacecnt'] > 0, 'fireplaceflag'] = "Yes"
df_train.loc[df_train['fireplaceflag'] != "Yes", 'fireplaceflag'] = "No"
df_train.loc[df_train['fireplacecnt'].isna(), 'fireplacecnt'] = 0

# %% [markdown]
# #### 9. Fill some features with the most common value for those variables where this might be a sensible approach:

# %% [markdown]
# (a) AC Type (airconditioningtypeid)- Mostly 1's, which corresponds to central AC. It is reasonable to assume most other properties where this feature is missing are similar.

# %%
df_train['airconditioningtypeid'] = 1

# %% [markdown]
# (b) heating or system (heatingorsystemtypeid)- Mostly 2, which corresponds to central heating so seems reasonable to assume most other properties have central heating.

# %%
df_train['heatingorsystemtypeid'] = 2

# %% [markdown]
# #### 10. If the features where missing proportion is too much, we can directly delete them. Here we set 97% as our threshold (This is subjective) and add them into the dropcols. Then drop those features in dropcols from the full table.

# %%
df_train.shape
# Out:
# (335776, 59)

# %%
filter_missing = df_train.isna().sum().to_frame().reset_index().rename(columns={'index':'feature_name', 0:'freq'})

# %%
filter_missing['freq'] = filter_missing['freq']/ 335776

# %%
dropcols_add = filter_missing[filter_missing['freq'] >= 0.97]['feature_name'].to_list()

# %%
dropcols = dropcols + dropcols_add

# %%
df_train = df_train.drop(dropcols, axis = 1)
